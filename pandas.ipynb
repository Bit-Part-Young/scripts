# %%
import pandas as pd

csv_fn = "AlNb_1_8.csv"
df = pd.read_csv(csv_fn)
df
# Out:
#                  structure_id conf_symbol  mixing_energy_pa    Al    Nb
# 0      ICET-Training-No-00002          Al          0.000000  1.00  0.00
# 1      ICET-Training-No-00003          Nb          0.000000  0.00  1.00
# 2      ICET-Training-No-00010        AlNb         -0.344455  0.50  0.50
# 3      ICET-Training-No-00020        AlNb         -0.083087  0.50  0.50
# 4      ICET-Training-No-00040       Al2Nb         -0.197581  0.67  0.33
# ..                        ...         ...               ...   ...   ...
# 161  ICET-Training-No-0284627       AlNb7         -0.072993  0.12  0.88
# 162  ICET-Training-No-0324940      Al3Nb5         -0.137374  0.38  0.62
# 163  ICET-Training-No-0365076      Al2Nb6         -0.181077  0.25  0.75
# 164  ICET-Training-No-0375387      Al3Nb5         -0.226562  0.38  0.62
# 165  ICET-Training-No-0389083      Al4Nb4         -0.295234  0.50  0.50
#
# [166 rows x 5 columns]

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df.loc[10:20]
# Out:
#               structure_id conf_symbol  mixing_energy_pa    Al    Nb
# 10  ICET-Training-No-00176       Al3Nb         -0.202412  0.75  0.25
# 11  ICET-Training-No-00179      Al2Nb2         -0.155968  0.50  0.50
# 12  ICET-Training-No-00187       AlNb3         -0.145466  0.25  0.75
# 13  ICET-Training-No-00281       Al3Nb         -0.282509  0.75  0.25
# 14  ICET-Training-No-00284      Al2Nb2         -0.336692  0.50  0.50
# 15  ICET-Training-No-00292       AlNb3         -0.134517  0.25  0.75
# 16  ICET-Training-No-00386       Al3Nb         -0.242424  0.75  0.25
# 17  ICET-Training-No-00389      Al2Nb2         -0.210254  0.50  0.50
# 18  ICET-Training-No-00397       AlNb3         -0.182559  0.25  0.75
# 19  ICET-Training-No-00491       Al3Nb         -0.266125  0.75  0.25
# 20  ICET-Training-No-00494      Al2Nb2         -0.296834  0.50  0.50

# %%
df.iloc[10:20]
# Out:
#               structure_id conf_symbol  mixing_energy_pa    Al    Nb
# 10  ICET-Training-No-00176       Al3Nb         -0.202412  0.75  0.25
# 11  ICET-Training-No-00179      Al2Nb2         -0.155968  0.50  0.50
# 12  ICET-Training-No-00187       AlNb3         -0.145466  0.25  0.75
# 13  ICET-Training-No-00281       Al3Nb         -0.282509  0.75  0.25
# 14  ICET-Training-No-00284      Al2Nb2         -0.336692  0.50  0.50
# 15  ICET-Training-No-00292       AlNb3         -0.134517  0.25  0.75
# 16  ICET-Training-No-00386       Al3Nb         -0.242424  0.75  0.25
# 17  ICET-Training-No-00389      Al2Nb2         -0.210254  0.50  0.50
# 18  ICET-Training-No-00397       AlNb3         -0.182559  0.25  0.75
# 19  ICET-Training-No-00491       Al3Nb         -0.266125  0.75  0.25
